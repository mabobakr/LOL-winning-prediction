# %%
import tensorflow as tf
# Out:
# 2022-05-21 19:56:40.212679: E tensorflow/core/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/api/oss-keras/optimizers
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# /media/mohammed/New Volume/4th year 2nd semster/machine learning/project/svm-lol.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/media/mohammed/New%20Volume/4th%20year%202nd%20semster/machine%20learning/project/svm-lol.ipynb#ch0000000?line=0'>1</a> import tensorflow as tf
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py:473, in <module>
#     <a href='file:///home/mohammed/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py?line=470'>471</a> if hasattr(_current_module, "keras"):
#     <a href='file:///home/mohammed/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py?line=471'>472</a>   try:
# ...
