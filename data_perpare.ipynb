# %%
# !pip install sklearn pandas matplotlib

# %%
import pandas as pd
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("data/high_diamond_ranked_10min.csv").dropna()
data.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
def histogram(valuesArray, title="histo"):
    plt.figure()
    plt.title(title)
    plt.hist(valuesArray)

# %%
histogram(data["blueWins"],"the histogram of wins and loses")

# %% [markdown]
# ## split the data to test and train before anything

# %%
train_data, test_data = train_test_split(data,test_size=.2)

# %% [markdown]
# ## zeroR and histograms
# since the dataset is almost balanced with the number os loses is almost equal to the number of wins I think that a zeroR algorithm will have an accuracy of 50% like random classification

# %%
histogram(train_data['blueWins'], "train hitogram")
histogram(test_data['blueWins'], "test histogram")

# %% [markdown]
# ## storing training and testing data

# %%
import os
os
if not os.path.exists("train"):
    os.mkdir("train")
if not os.path.exists("test"):
    os.mkdir("test")

train_data.to_csv('train/train.csv', index=False)
test_data.to_csv('test/test.csv', index=False)

# %%
pd.read_csv("train/train.csv").dropna()
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4521252780         1               11                   2
# 1     4516789805         1               17                   2
# 2     4517546735         1               85                   6
# 3     4508668617         0               17                   3
# 4     4462493939         0               16                   2
# ...          ...       ...              ...                 ...
# 7898  4521281079         0               15                   2
# 7899  4387776096         0               16                   2
# 7900  4515493524         0               12                   5
# 7901  4527742166         0               20                   5
# 7902  4497571086         1               18                   5
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  0          5           5            1                  0
# ...

# %%
pd.read_csv("test/test.csv").dropna()
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4436906182         1               13                   1
# 1     4514312367         0               11                   1
# 2     4515527717         1               16                   3
# 3     4510817893         0               51                  10
# 4     4506258913         1               13                   2
# ...          ...       ...              ...                 ...
# 1971  4521845032         0               16                   5
# 1972  4490184459         0               18                   2
# 1973  4522301091         1               18                   5
# 1974  4511071650         0               15                   0
# 1975  4451891772         0               15                   3
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          4           6            5                  0
# ...
